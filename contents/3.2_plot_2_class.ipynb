# %% [markdown]
# ### Plotting with keyword strings

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
plt.scatter('a', 'b', color='c', size='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
data['b']
# Out:
# array([ 10.08069654,  14.82921587,   5.97019505,  15.65082618,
#         17.87188172,   8.59798292, -19.94848389,  16.04702617,
#         -0.86160183,  10.37977367,  18.17176018, -10.01096787,
#          9.14647817,  19.1451436 ,  23.18845232,  21.637871  ,
#         24.97842882,  23.31920842,   4.17566602,  20.35790647,
#         25.21828628,  21.12105723,  24.28049662,  24.40303042,
#         31.49168517,  31.80340531,  40.20336429,  28.38169911,
#         25.91179618,  33.57645601,  27.18723363,  32.679167  ,
#         45.74805627,  37.88622622,  32.51118422,  30.7275693 ,
#         29.83954254,  35.09540327,  38.42931756,  26.7923361 ,
#         28.98217374,  36.34707424,  51.80446789,  45.61242587,
#         39.96104472,  46.17424654,  33.38407531,  52.60839956,
#         47.92862956,  59.23816379])

# %%
result = plt.hist(data['b'], density=False, bins=10, edgecolor='black', alpha=0.5)

print(result[0])
# Out:
# [ 1.  1.  1.  6.  6. 12. 11.  5.  4.  3.]

# %%
result = plt.hist(data['b'], density=True, bins=10, edgecolor='black', alpha=0.5)

print(result[0])
# Out:
# [0.00252568 0.00252568 0.00252568 0.01515407 0.01515407 0.03030814
#  0.02778246 0.01262839 0.01010271 0.00757703]

# %% [markdown]
# ### Plotting with categorical variables

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

# %% [markdown]
# ### Working with multiple figures and axes

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

# %% [markdown]
# ### Working with text

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# %% [markdown]
# ### Annotating text

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)

# %% [markdown]
# ### Logarithmic and other nonlinear axes#

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))
